# %% [markdown]
# <a href="https://colab.research.google.com/github/Ezemettler/PI1-MLOps/blob/main/ETL_Transformaciones.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##Transformaciones:
#
# Para este MVP no necesitas perfección, ¡necesitas rapidez! ⏩ Vas a hacer estas, y solo estas, transformaciones a los datos:
#
# * Generar campo id: Cada id se compondrá de la primera letra del nombre de la plataforma, seguido del show_id ya presente en los datasets (ejemplo para títulos de Amazon = as123)

# %%
# Vinculamos google colab con google drive para importar el dataset

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Importamos librerias

import pandas as pd

# %%
# Levantamos los datasets, guardamos cada uno en una variable distinta y agregamos la columna Id

data_amazon = pd.read_csv('/content/drive/MyDrive/Formación/Henry/PI N°1 - MLOps/amazon_prime_titles.csv', sep=',', encoding='latin-1')
data_amazon['Id'] = 'a' + data_amazon['show_id']

data_disney = pd.read_csv('/content/drive/MyDrive/Formación/Henry/PI N°1 - MLOps/disney_plus_titles.csv', sep=',', encoding='latin-1')
data_disney['Id'] = 'd' + data_disney['show_id']

data_hulu = pd.read_csv('/content/drive/MyDrive/Formación/Henry/PI N°1 - MLOps/hulu_titles.csv', sep=',', encoding='latin-1')
data_hulu['Id'] = 'h' + data_hulu['show_id']

data_netflix = pd.read_csv('/content/drive/MyDrive/Formación/Henry/PI N°1 - MLOps/netflix_titles.csv', sep=',', encoding='latin-1')
data_netflix['Id'] = 'n' + data_netflix['show_id']

# %%
# Antes de unirlos, verificamos que los dataset tengan igual cant de columnas
# Tambien ver cant de filas, para luego sumarlas y verificar que todas se agregaron al dataset total

print(data_amazon.shape)
print(data_disney.shape)
print(data_hulu.shape)
print(data_netflix.shape)
# Out:
# (9668, 13)
# (1450, 13)
# (3073, 13)
# (8807, 13)

# %%
# Unimos los dataset en uno solo

data_plataformas = pd.concat([data_amazon, data_disney, data_hulu, data_netflix])
data_plataformas.head()
# Out:
#   show_id   type                 title        director  \
# 0      s1  Movie   The Grand Seduction    Don McKellar
# 1      s2  Movie  Take Care Good Night    Girish Joshi
# 2      s3  Movie  Secrets of Deception     Josh Webber
# 3      s4  Movie    Pink: Staying True  Sonia Anderson
# 4      s5  Movie         Monster Maker    Giles Foster
#
#                                                 cast         country  \
# 0     Brendan Gleeson, Taylor Kitsch, Gordon Pinsent          Canada
# 1   Mahesh Manjrekar, Abhay Mahajan, Sachin Khedekar           India
# 2  Tom Sizemore, Lorenzo Lamas, Robert LaSardo, R...   United States
# 3  Interviews with: Pink, Adele, BeyoncÃ©, Britne...   United States
# 4  Harry Dean Stanton, Kieran O'Brien, George Cos...  United Kingdom
#
#        date_added  release_year rating duration                listed_in  \
# 0  March 30, 2021          2014    NaN  113 min            Comedy, Drama
# ...

# %%
# Cant de registros y columnas del dataset de las plataformas

data_plataformas.shape
# Out:
# (22998, 13)

# %% [markdown]
# * Los valores nulos del campo rating deberán reemplazarse por el string “G” (corresponde al maturity rating: “general for all audiences”

# %%
# Verificamos cuantos valores nulos hay por cada columna

data_plataformas.isna().sum()
# Out:
# show_id             0
# type                0
# title               0
# director         8259
# cast             5321
# country         11499
# date_added       9554
# release_year        0
# rating            864
# duration          482
# listed_in           0
# description         4
# Id                  0
# dtype: int64

# %%
# Reemplazamos los valores nulos de la columna Rating por G

data_plataformas['rating'].fillna('g', inplace=True)
data_plataformas.head()
# Out:
#   show_id   type                 title        director  \
# 0      s1  Movie   The Grand Seduction    Don McKellar
# 1      s2  Movie  Take Care Good Night    Girish Joshi
# 2      s3  Movie  Secrets of Deception     Josh Webber
# 3      s4  Movie    Pink: Staying True  Sonia Anderson
# 4      s5  Movie         Monster Maker    Giles Foster
#
#                                                 cast         country  \
# 0     Brendan Gleeson, Taylor Kitsch, Gordon Pinsent          Canada
# 1   Mahesh Manjrekar, Abhay Mahajan, Sachin Khedekar           India
# 2  Tom Sizemore, Lorenzo Lamas, Robert LaSardo, R...   United States
# 3  Interviews with: Pink, Adele, BeyoncÃ©, Britne...   United States
# 4  Harry Dean Stanton, Kieran O'Brien, George Cos...  United Kingdom
#
#        date_added  release_year rating duration                listed_in  \
# 0  March 30, 2021          2014      g  113 min            Comedy, Drama
# ...

# %%
# Verificamos que la columna rating no cuenta con valores nulos luego de reemplazarlos.

data_plataformas['rating'].isna().sum()
# Out:
# 0

# %% [markdown]
# * De haber fechas, deberán tener el formato AAAA-mm-dd

# %%
# Cambiamos el formato fecha a aaaa-mm-dd

data_plataformas['date_added'] = pd.to_datetime(data_plataformas['date_added'])
data_plataformas.head()
# Out:
#   show_id   type                 title        director  \
# 0      s1  Movie   The Grand Seduction    Don McKellar
# 1      s2  Movie  Take Care Good Night    Girish Joshi
# 2      s3  Movie  Secrets of Deception     Josh Webber
# 3      s4  Movie    Pink: Staying True  Sonia Anderson
# 4      s5  Movie         Monster Maker    Giles Foster
#
#                                                 cast         country  \
# 0     Brendan Gleeson, Taylor Kitsch, Gordon Pinsent          Canada
# 1   Mahesh Manjrekar, Abhay Mahajan, Sachin Khedekar           India
# 2  Tom Sizemore, Lorenzo Lamas, Robert LaSardo, R...   United States
# 3  Interviews with: Pink, Adele, BeyoncÃ©, Britne...   United States
# 4  Harry Dean Stanton, Kieran O'Brien, George Cos...  United Kingdom
#
#   date_added  release_year rating duration                listed_in  \
# 0 2021-03-30          2014      g  113 min            Comedy, Drama
# 1 2021-03-30          2018    13+  110 min     Drama, International
# ...

# %% [markdown]
# * Los campos de texto deberán estar en minúsculas, sin excepciones

# %%
# Todos los campos textos pasan a minusculas

data_plataformas['type'] = data_plataformas['type'].str.lower()
data_plataformas['title'] = data_plataformas['title'].str.lower()
data_plataformas['director'] = data_plataformas['director'].str.lower()
data_plataformas['cast'] = data_plataformas['cast'].str.lower()
data_plataformas['country'] = data_plataformas['country'].str.lower()
data_plataformas['rating'] = data_plataformas['rating'].str.lower()
data_plataformas['duration'] = data_plataformas['duration'].str.lower()
data_plataformas['listed_in'] = data_plataformas['listed_in'].str.lower()
data_plataformas['description'] = data_plataformas['description'].str.lower()
data_plataformas['Id'] = data_plataformas['Id'].str.lower()
data_plataformas.head()
# Out:
#   show_id   type                 title        director  \
# 0      s1  movie   the grand seduction    don mckellar
# 1      s2  movie  take care good night    girish joshi
# 2      s3  movie  secrets of deception     josh webber
# 3      s4  movie    pink: staying true  sonia anderson
# 4      s5  movie         monster maker    giles foster
#
#                                                 cast         country  \
# 0     brendan gleeson, taylor kitsch, gordon pinsent          canada
# 1   mahesh manjrekar, abhay mahajan, sachin khedekar           india
# 2  tom sizemore, lorenzo lamas, robert lasardo, r...   united states
# 3  interviews with: pink, adele, beyoncã©, britne...   united states
# 4  harry dean stanton, kieran o'brien, george cos...  united kingdom
#
#   date_added  release_year rating duration                listed_in  \
# 0 2021-03-30          2014      g  113 min            comedy, drama
# 1 2021-03-30          2018    13+  110 min     drama, international
# ...

# %% [markdown]
# * El campo duration debe convertirse en dos campos: duration_int y duration_type. El primero será un integer y el segundo un string indicando la unidad de medición de duración: min (minutos) o season (temporadas)

# %%
# Extraemos la cant de la columna duración

data_plataformas['duration_int'] = data_plataformas['duration'].str.extract('([0-9]+)')
data_plataformas.head()
# Out:
#   show_id   type                 title        director  \
# 0      s1  movie   the grand seduction    don mckellar
# 1      s2  movie  take care good night    girish joshi
# 2      s3  movie  secrets of deception     josh webber
# 3      s4  movie    pink: staying true  sonia anderson
# 4      s5  movie         monster maker    giles foster
#
#                                                 cast         country  \
# 0     brendan gleeson, taylor kitsch, gordon pinsent          canada
# 1   mahesh manjrekar, abhay mahajan, sachin khedekar           india
# 2  tom sizemore, lorenzo lamas, robert lasardo, r...   united states
# 3  interviews with: pink, adele, beyoncã©, britne...   united states
# 4  harry dean stanton, kieran o'brien, george cos...  united kingdom
#
#   date_added  release_year rating duration                listed_in  \
# 0 2021-03-30          2014      g  113 min            comedy, drama
# 1 2021-03-30          2018    13+  110 min     drama, international
# ...

# %%
# Extraemos el tipo de duración de la columna duración

data_plataformas['duration_type'] = data_plataformas['duration'].str.extract('([a-z]+)')
data_plataformas.head()
# Out:
#   show_id   type                 title        director  \
# 0      s1  movie   the grand seduction    don mckellar
# 1      s2  movie  take care good night    girish joshi
# 2      s3  movie  secrets of deception     josh webber
# 3      s4  movie    pink: staying true  sonia anderson
# 4      s5  movie         monster maker    giles foster
#
#                                                 cast         country  \
# 0     brendan gleeson, taylor kitsch, gordon pinsent          canada
# 1   mahesh manjrekar, abhay mahajan, sachin khedekar           india
# 2  tom sizemore, lorenzo lamas, robert lasardo, r...   united states
# 3  interviews with: pink, adele, beyoncã©, britne...   united states
# 4  harry dean stanton, kieran o'brien, george cos...  united kingdom
#
#   date_added  release_year rating duration                listed_in  \
# 0 2021-03-30          2014      g  113 min            comedy, drama
# 1 2021-03-30          2018    13+  110 min     drama, international
# ...

# %%
# Eliminamos las columnas sobrantes

data_plataformas.drop(['show_id'], axis=1, inplace=True)
data_plataformas.drop(['duration'], axis=1, inplace=True)
data_plataformas.head()
# Out:
#     type                 title        director  \
# 0  movie   the grand seduction    don mckellar
# 1  movie  take care good night    girish joshi
# 2  movie  secrets of deception     josh webber
# 3  movie    pink: staying true  sonia anderson
# 4  movie         monster maker    giles foster
#
#                                                 cast         country  \
# 0     brendan gleeson, taylor kitsch, gordon pinsent          canada
# 1   mahesh manjrekar, abhay mahajan, sachin khedekar           india
# 2  tom sizemore, lorenzo lamas, robert lasardo, r...   united states
# 3  interviews with: pink, adele, beyoncã©, britne...   united states
# 4  harry dean stanton, kieran o'brien, george cos...  united kingdom
#
#   date_added  release_year rating                listed_in  \
# 0 2021-03-30          2014      g            comedy, drama
# 1 2021-03-30          2018    13+     drama, international
# 2 2021-03-30          2017      g  action, drama, suspense
# ...

# %%
# Verificamos que campos tienen valores nulos

data_plataformas.isna().sum()
# Out:
# type                 0
# title                0
# director          8259
# cast              5321
# country          11499
# date_added        9554
# release_year         0
# rating               0
# listed_in            0
# description          4
# Id                   0
# duration_int       482
# duration_type      482
# dtype: int64

# %%
# Completamos los valores nulos del campo "duration_int" con 0

data_plataformas['duration_int'].fillna(0, inplace=True)
data_plataformas['duration_int'].isna().sum()
# Out:
# 0

# %%
# Llenamos los campos vacios con tipo de dato string con la leyenda "sin dato"

data_plataformas['director'].fillna('sin dato', inplace=True)
data_plataformas['cast'].fillna('sin dato', inplace=True)
data_plataformas['country'].fillna('sin dato', inplace=True)
data_plataformas['duration_type'].fillna('sin dato', inplace=True)
data_plataformas
# Out:
#          type                 title         director  \
# 0       movie   the grand seduction     don mckellar
# 1       movie  take care good night     girish joshi
# 2       movie  secrets of deception      josh webber
# 3       movie    pink: staying true   sonia anderson
# 4       movie         monster maker     giles foster
# ...       ...                   ...              ...
# 8802    movie                zodiac    david fincher
# 8803  tv show           zombie dumb         sin dato
# 8804    movie            zombieland  ruben fleischer
# 8805    movie                  zoom     peter hewitt
# 8806    movie                zubaan      mozez singh
#
#                                                    cast         country  \
# 0        brendan gleeson, taylor kitsch, gordon pinsent          canada
# 1      mahesh manjrekar, abhay mahajan, sachin khedekar           india
# 2     tom sizemore, lorenzo lamas, robert lasardo, r...   united states
# ...

# %%
# Verificamos si en duration_type, que aparezcan valores unicos.

data_plataformas_type = data_plataformas['duration_type'].unique()
data_plataformas_type
# Out:
# array(['min', 'season', 'seasons', 'sin dato'], dtype=object)

# %%
# Unificamos los valores de seasons

data_plataformas['duration_type'].replace({'season': 'seasons'}, inplace=True)
data_plataformas
# Out:
#          type                 title         director  \
# 0       movie   the grand seduction     don mckellar
# 1       movie  take care good night     girish joshi
# 2       movie  secrets of deception      josh webber
# 3       movie    pink: staying true   sonia anderson
# 4       movie         monster maker     giles foster
# ...       ...                   ...              ...
# 8802    movie                zodiac    david fincher
# 8803  tv show           zombie dumb         sin dato
# 8804    movie            zombieland  ruben fleischer
# 8805    movie                  zoom     peter hewitt
# 8806    movie                zubaan      mozez singh
#
#                                                    cast         country  \
# 0        brendan gleeson, taylor kitsch, gordon pinsent          canada
# 1      mahesh manjrekar, abhay mahajan, sachin khedekar           india
# 2     tom sizemore, lorenzo lamas, robert lasardo, r...   united states
# ...

# %%
# Verificamos que los valores únicos del campo 'duration_time' sean correctos

data_plataformas_type = data_plataformas['duration_type'].unique()
data_plataformas_type
# Out:
# array(['min', 'seasons', 'sin dato'], dtype=object)

# %%
# Verificamos que no hayan quedado valores nulos, salvo los campos con formato fecha (date)

data_plataformas.isna().sum()
# Out:
# type                0
# title               0
# director            0
# cast                0
# country             0
# date_added       9554
# release_year        0
# rating              0
# listed_in           0
# description         4
# Id                  0
# duration_int        0
# duration_type       0
# dtype: int64

# %%
# Levantamos cada csv con los rating de las peliculas

rating1 = pd.read_csv('/content/drive/MyDrive/Formación/Henry/PI N°1 - MLOps/ratings/1.csv', sep=',', encoding='latin-1')
rating2 = pd.read_csv('/content/drive/MyDrive/Formación/Henry/PI N°1 - MLOps/ratings/2.csv', sep=',', encoding='latin-1')
rating3 = pd.read_csv('/content/drive/MyDrive/Formación/Henry/PI N°1 - MLOps/ratings/3.csv', sep=',', encoding='latin-1')
rating4 = pd.read_csv('/content/drive/MyDrive/Formación/Henry/PI N°1 - MLOps/ratings/4.csv', sep=',', encoding='latin-1')
rating5 = pd.read_csv('/content/drive/MyDrive/Formación/Henry/PI N°1 - MLOps/ratings/5.csv', sep=',', encoding='latin-1')
rating6 = pd.read_csv('/content/drive/MyDrive/Formación/Henry/PI N°1 - MLOps/ratings/6.csv', sep=',', encoding='latin-1')
rating7 = pd.read_csv('/content/drive/MyDrive/Formación/Henry/PI N°1 - MLOps/ratings/7.csv', sep=',', encoding='latin-1')
rating8 = pd.read_csv('/content/drive/MyDrive/Formación/Henry/PI N°1 - MLOps/ratings/8.csv', sep=',', encoding='latin-1')

print(rating1.shape)
print(rating2.shape)
print(rating3.shape)
print(rating4.shape)
print(rating5.shape)
print(rating6.shape)
print(rating7.shape)
print(rating8.shape)
# Out:
# (1500000, 4)
# (1500000, 4)
# (1500000, 4)
# (1500000, 4)
# (1500000, 4)
# (1500000, 4)
# (524289, 4)
# (1500000, 4)

# %%
# Unimos los dataset de ratings

data_score = pd.concat([rating1, rating2, rating3, rating4, rating5, rating6, rating7, rating8])
data_score.shape
# Out:
# (11024289, 4)

# %%
# Verificamos si tienen valores nulos o faltantes

data_score.isna().sum()
# Out:
# userId       0
# rating       0
# timestamp    0
# movieId      0
# dtype: int64

# %%
# Creamos un nuevo dataset para agrupar el rating promedio por pelicula

data_score_prom = data_score.groupby(['movieId']).mean()
data_score_prom
# Out:
#                userId    rating     timestamp
# movieId
# as1      99178.623506  3.467131  1.173241e+09
# as10     92915.883041  3.439571  1.176385e+09
# as100    83483.262791  3.609302  1.165458e+09
# as1000   90606.197938  3.556701  1.168386e+09
# as1001   92349.085288  3.585288  1.179517e+09
# ...               ...       ...           ...
# ns995    86366.176339  3.515625  1.176070e+09
# ns996    94741.060729  3.626518  1.159029e+09
# ns997    86417.856842  3.530526  1.162038e+09
# ns998    94409.502066  3.582645  1.173053e+09
# ns999    90685.066806  3.494781  1.165742e+09
#
# [22998 rows x 3 columns]

# %%
# Unimos ambos dataset, mientras que el id de cada uno coincida

data_plataformas_prom = pd.merge(left=data_plataformas, right=data_score_prom, how='left', left_on='Id', right_on='movieId')
data_plataformas_prom.head()
# Out:
#     type                 title        director  \
# 0  movie   the grand seduction    don mckellar
# 1  movie  take care good night    girish joshi
# 2  movie  secrets of deception     josh webber
# 3  movie    pink: staying true  sonia anderson
# 4  movie         monster maker    giles foster
#
#                                                 cast         country  \
# 0     brendan gleeson, taylor kitsch, gordon pinsent          canada
# 1   mahesh manjrekar, abhay mahajan, sachin khedekar           india
# 2  tom sizemore, lorenzo lamas, robert lasardo, r...   united states
# 3  interviews with: pink, adele, beyoncã©, britne...   united states
# 4  harry dean stanton, kieran o'brien, george cos...  united kingdom
#
#   date_added  release_year rating_x                listed_in  \
# 0 2021-03-30          2014        g            comedy, drama
# 1 2021-03-30          2018      13+     drama, international
# 2 2021-03-30          2017        g  action, drama, suspense
# ...

# %%
# Eliminamos las columnas que nos sobran (userId y timestamp)

data_plataformas_prom.drop(['userId'], axis=1, inplace=True)
data_plataformas_prom.drop(['timestamp'], axis=1, inplace=True)
data_plataformas_prom
# Out:
#           type                 title         director  \
# 0        movie   the grand seduction     don mckellar
# 1        movie  take care good night     girish joshi
# 2        movie  secrets of deception      josh webber
# 3        movie    pink: staying true   sonia anderson
# 4        movie         monster maker     giles foster
# ...        ...                   ...              ...
# 22993    movie                zodiac    david fincher
# 22994  tv show           zombie dumb         sin dato
# 22995    movie            zombieland  ruben fleischer
# 22996    movie                  zoom     peter hewitt
# 22997    movie                zubaan      mozez singh
#
#                                                     cast         country  \
# 0         brendan gleeson, taylor kitsch, gordon pinsent          canada
# 1       mahesh manjrekar, abhay mahajan, sachin khedekar           india
# 2      tom sizemore, lorenzo lamas, robert lasardo, r...   united states
# ...

# %%
# Cambiamos el nombre de la columna rating por score

data_plataformas_prom.rename(columns={'rating_y':'score'}, inplace=True)
data_plataformas_prom
# Out:
#           type                 title         director  \
# 0        movie   the grand seduction     don mckellar
# 1        movie  take care good night     girish joshi
# 2        movie  secrets of deception      josh webber
# 3        movie    pink: staying true   sonia anderson
# 4        movie         monster maker     giles foster
# ...        ...                   ...              ...
# 22993    movie                zodiac    david fincher
# 22994  tv show           zombie dumb         sin dato
# 22995    movie            zombieland  ruben fleischer
# 22996    movie                  zoom     peter hewitt
# 22997    movie                zubaan      mozez singh
#
#                                                     cast         country  \
# 0         brendan gleeson, taylor kitsch, gordon pinsent          canada
# 1       mahesh manjrekar, abhay mahajan, sachin khedekar           india
# 2      tom sizemore, lorenzo lamas, robert lasardo, r...   united states
# ...

# %%
# Redondeamos los campos float a 1 solo decimal

data_plataformas_prom = data_plataformas_prom.round(1)
data_plataformas_prom
# Out:
#           type                 title         director  \
# 0        movie   the grand seduction     don mckellar
# 1        movie  take care good night     girish joshi
# 2        movie  secrets of deception      josh webber
# 3        movie    pink: staying true   sonia anderson
# 4        movie         monster maker     giles foster
# ...        ...                   ...              ...
# 22993    movie                zodiac    david fincher
# 22994  tv show           zombie dumb         sin dato
# 22995    movie            zombieland  ruben fleischer
# 22996    movie                  zoom     peter hewitt
# 22997    movie                zubaan      mozez singh
#
#                                                     cast         country  \
# 0         brendan gleeson, taylor kitsch, gordon pinsent          canada
# 1       mahesh manjrekar, abhay mahajan, sachin khedekar           india
# 2      tom sizemore, lorenzo lamas, robert lasardo, r...   united states
# ...

# %%
# Info general del dataset final

data_plataformas_prom.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 22998 entries, 0 to 22997
# Data columns (total 14 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   type           22998 non-null  object
#  1   title          22998 non-null  object
#  2   director       22998 non-null  object
#  3   cast           22998 non-null  object
#  4   country        22998 non-null  object
#  5   date_added     13444 non-null  datetime64[ns]
#  6   release_year   22998 non-null  int64
#  7   rating_x       22998 non-null  object
#  8   listed_in      22998 non-null  object
#  9   description    22994 non-null  object
#  10  Id             22998 non-null  object
#  11  duration_int   22998 non-null  object
#  12  duration_type  22998 non-null  object
#  13  score          22998 non-null  float64
# dtypes: datetime64[ns](1), float64(1), int64(1), object(11)
# memory usage: 2.6+ MB

# %%
# Generamos el csv que trabajamos con los datasets de las plataformas y el score promedio para usarlo en la Api

data_plataformas_prom.to_csv('/content/drive/MyDrive/Formación/Henry/PI N°1 - MLOps/plataformas_prom.csv', index=False)

# %%
# Ahora debemos dejar listo el dataset con los score, sin filtrar datos, con el formato correcto

data_score.head()
# Out:
#    userId  rating   timestamp movieId
# 0       1     1.0  1425941529   as680
# 1       1     4.5  1425942435  ns2186
# 2       1     5.0  1425941523  hs2381
# 3       1     5.0  1425941546  ns3663
# 4       1     5.0  1425941556  as9500

# %%
# Valores nulos ya habiamos verificado y no tiene.

# Ahora pasamos a cambiar el formato fecha unix a formato fecha aaaa-mm-dd

data_score['timestamp'] = pd.to_datetime(data_score['timestamp'], unit='s').dt.strftime('%Y-%m-%d')
data_score
# Out:
#          userId  rating   timestamp movieId
# 0             1     1.0  2015-03-09   as680
# 1             1     4.5  2015-03-09  ns2186
# 2             1     5.0  2015-03-09  hs2381
# 3             1     5.0  2015-03-09  ns3663
# 4             1     5.0  2015-03-09  as9500
# ...         ...     ...         ...     ...
# 1499995  124380     4.5  2007-12-04  ns5272
# 1499996  124380     2.5  2007-12-04  ns5492
# 1499997  124380     3.5  2007-12-04   hs305
# 1499998  124380     4.5  2007-12-04  ns7881
# 1499999  124380     1.5  2007-12-04   as883
#
# [11024289 rows x 4 columns]

# %%
# Verificamos si existen registros duplicados

data_score.duplicated().sum()
# Out:
# 10466

# %%
# Eliminamos los valores duplicados

data_score.drop_duplicates(inplace=True)

# %%
# Verificamos que la cant de registros se hayan reducido en 10466

print("Nueva cant registros:", data_score.shape[0])
# Out:
# Nueva cant registros: 11013823

# %%
# Verificamos el tipo de dato de cada columna, y el espacio que ocupará el dataset en memoria

data_score.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 11013823 entries, 0 to 1499999
# Data columns (total 4 columns):
#  #   Column     Dtype
# ---  ------     -----
#  0   userId     int64
#  1   rating     float64
#  2   timestamp  object
#  3   movieId    object
# dtypes: float64(1), int64(1), object(2)
# memory usage: 420.1+ MB

# %%
# Verificamos que existan valores unicos y de un solo tipo de dato en la columna rating

data_score['rating'].unique()
# Out:
# array([1. , 4.5, 5. , 4. , 3.5, 2.5, 0.5, 3. , 2. , 1.5])

# %%
# Generamos el csv que trabajamos con los datasets de ratings

data_score.to_csv('/content/drive/MyDrive/Formación/Henry/PI N°1 - MLOps/score.csv', index=False)
